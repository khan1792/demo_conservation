# %%
import pandas as pd
import streamlit as st

# %%
occur = pd.read_csv('funder_occur.csv')

# %%
label = pd.read_csv('topic_name.csv')

# %%
final = pd.read_csv('final_data.txt.gz')

# %%
topic = pd.read_csv('topic.txt.gz')

# %%
ind = pd.read_csv('index.csv')

# %%
ind.columns = ['no', 'X', 'paper_id', 'document', 'Times.Cited..All.Databases', 'Publication.Year']

# %%
abc = pd.read_csv('model100result.csv')

# %%
aabbcc = abc[abc['Publication Year']>=1970]

# %%
# Out:
#         Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 1011        0.000254         0.015637        0.000132            0.013964
# 1054        0.000278         0.007723        0.000124            0.000153
# 1057        0.000311         0.012997        0.000376            0.001932
# 1062        0.000559         0.007671        0.000853            0.000640
# 1080        0.000266         0.044979        0.000147            0.000448
# ...              ...              ...             ...                 ...
# 120132      0.000138         0.001632        0.000079            0.006151
# 120133      0.000382         0.010109        0.000198            0.001217
# 120135      0.013246         0.006664        0.001296            0.001772
# 120136      0.000335         0.002363        0.000451            0.014920
# 120137      0.000494         0.016941        0.001999            0.015275
#
#         Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
topic
# Out:
#         Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 0           0.025251         0.009361        0.001245            0.006362
# 1           0.223404         0.004913        0.001185            0.000102
# 2           0.000869         0.033810        0.001141            0.000101
# 3           0.000633         0.001802        0.013577            0.000601
# 4           0.006979         0.003375        0.000711            0.000996
# ...              ...              ...             ...                 ...
# 120133      0.000382         0.010109        0.000198            0.001217
# 120134      0.000503         0.006859        0.000873            0.000027
# 120135      0.013246         0.006664        0.001296            0.001772
# 120136      0.000335         0.002363        0.000451            0.014920
# 120137      0.000494         0.016941        0.001999            0.015275
#
#         Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
topic = pd.merge(topic, ind, 'left')

# %%
topic = topic.drop(['Unnamed: 0', 'no', 'X', 'document'],1)
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_32202/3071002950.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   topic = topic.drop(['Unnamed: 0', 'no', 'X', 'document'],1)

# %%
topic.columns = label['topic'].tolist() + ['paper_id','Times.Cited..All.Databases', 'Publication.Year']

# %%
topic_name

# %%
topic.to_csv('topic.txt.gz', index = False)

# %%
topic.drop(['Unnamed: 0', 'paper_id'],1)
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_32202/2151085179.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   topic.drop(['Unnamed: 0', 'paper_id'],1)
#               t1        t2        t3        t4        t5        t6        t7  \
# 0       0.025251  0.009361  0.001245  0.006362  0.000692  0.001479  0.000608
# 1       0.223404  0.004913  0.001185  0.000102  0.000200  0.000280  0.006138
# 2       0.000869  0.033810  0.001141  0.000101  0.000091  0.000050  0.000933
# 3       0.000633  0.001802  0.013577  0.000601  0.002152  0.023578  0.000264
# 4       0.006979  0.003375  0.000711  0.000996  0.000035  0.000050  0.003421
# ...          ...       ...       ...       ...       ...       ...       ...
# 122351  0.000382  0.010109  0.000198  0.001217  0.000332  0.001373  0.008039
# 122352  0.000503  0.006859  0.000873  0.000027  0.000043  0.000015  0.000479
# ...

# %%
topic = topic.dropna()
topic['Publication.Year'] = topic['Publication.Year'].apply(lambda x: int(x))
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_32202/961704035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   topic['Publication.Year'] = topic['Publication.Year'].apply(lambda x: int(x))

# %%
topic
# Out:
#         Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 0           0.025251         0.009361        0.001245            0.006362
# 1           0.223404         0.004913        0.001185            0.000102
# 2           0.000869         0.033810        0.001141            0.000101
# 3           0.000633         0.001802        0.013577            0.000601
# 4           0.006979         0.003375        0.000711            0.000996
# ...              ...              ...             ...                 ...
# 120133      0.000382         0.010109        0.000198            0.001217
# 120134      0.000503         0.006859        0.000873            0.000027
# 120135      0.013246         0.006664        0.001296            0.001772
# 120136      0.000335         0.002363        0.000451            0.014920
# 120137      0.000494         0.016941        0.001999            0.015275
#
#         Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
oo = topic[topic['paper_id'].isin(final['paper_id'].tolist())].groupby('Publication.Year').mean()
oo['pub'] = oo.index

# %%
oo[oo.index >= 2007].to_csv('topic_trend_funded.csv', index = False)

# %%
oo['type'] = 'Funded'

# %%
ooo.to_csv('topic_trend.csv', index = False)

# %%
oo1 = pd.read_csv('topic_trend.csv')

# %%
oo1['type'] = 'All'

# %%
ooo1 = pd.concat([oo[oo['pub'] >= 1970],oo1])

# %%
import seaborn as sns
sns.regplot(data=oo, x='pub', y='Protected areas', scatter = False, lowess = True)
# Out:
# <AxesSubplot:xlabel='pub', ylabel='Protected areas'>

# %%
oo[oo['pub'] >= 1970]
# Out:
#                   Wild Mammals  Protected areas  Marine mammals  \
# Publication.Year
# 1970.0                0.023110         0.012377        0.008095
# 1971.0                0.001588         0.011126        0.001413
# 1972.0                0.002158         0.015266        0.001207
# 1973.0                0.002411         0.015288        0.003211
# 1974.0                0.002014         0.011853        0.002007
# 1975.0                0.007608         0.017071        0.002153
# 1976.0                0.002705         0.013599        0.002339
# 1977.0                0.002220         0.012556        0.016024
# 1978.0                0.006036         0.012857        0.001953
# 1979.0                0.012141         0.012933        0.001428
# 1980.0                0.002371         0.015525        0.002314
# 1981.0                0.002678         0.013947        0.002196
# 1982.0                0.017587         0.013907        0.002326
# ...

# %%
ooo
# Out:
#         Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 1970.0      0.023110         0.012377        0.008095            0.005960
# 1971.0      0.001588         0.011126        0.001413            0.028504
# 1972.0      0.002158         0.015266        0.001207            0.008125
# 1973.0      0.002411         0.015288        0.003211            0.065442
# 1974.0      0.002014         0.011853        0.002007            0.011821
# ...              ...              ...             ...                 ...
# 47.0        0.003119         0.015992        0.007289            0.008185
# 48.0        0.002749         0.016693        0.005239            0.007650
# 49.0        0.002738         0.016411        0.004933            0.007548
# 50.0        0.002488         0.016547        0.006606            0.009313
# 51.0        0.001814         0.013317        0.003409            0.007599
#
#         Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
ggplot(ooo[ooo['pub']!=2021], aes('pub', 'Marine mammals', color = 'type')) + geom_smooth(se = False) + theme(figure_size=(12, 5)) + geom_point()
# Out:
# <ggplot: (8761070505138)>

# %%
ggplot(ooo1[ooo1['pub']!= 2021], aes('pub', 'Marine mammals', color = 'type')) + geom_smooth(se = False) + theme(figure_size=(12, 5)) + geom_point()
# Out:
# <ggplot: (8761063936904)>

# %%
oo
# Out:
#                   Wild Mammals  Protected areas  Marine mammals  \
# Publication.Year
# 1970.0                0.003009         0.013035        0.003813
# 1971.0                0.002789         0.013160        0.002158
# 1972.0                0.004558         0.015257        0.003965
# 1973.0                0.008632         0.013578        0.003270
# 1974.0                0.005194         0.016660        0.002465
# 1975.0                0.002926         0.012740        0.003434
# 1976.0                0.004335         0.014349        0.002456
# 1977.0                0.005244         0.016059        0.004633
# 1978.0                0.005608         0.017963        0.005704
# 1979.0                0.003783         0.018080        0.002456
# 1980.0                0.005540         0.017234        0.004515
# 1981.0                0.004910         0.016557        0.003646
# 1982.0                0.005975         0.018537        0.003032
# ...

# %%
oo.to_csv('topic_trend.csv', index = False)

# %%
pip install pygam
# Out:
# ...
#      |████████████████████████████████| 522 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 35.2 MB 2.8 MB/s eta 0:00:01     |██████████████████              | 19.9 MB 6.3 MB/s eta 0:00:03
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rpy2
# Out:
# ...
#      |████████████████████████████████| 216 kB 1.8 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/vn54nkz/opt/anaconda3/bin/python /Users/vn54nkz/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/tmppvy1ljxd
#        cwd: /private/var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/pip-install-ppbp3jgw/rpy2_c6f63c82add9439697feebd37c3790b7
#   Complete output (6 lines):
#   Unable to determine R home: [Errno 2] No such file or directory: 'R'
#   cffi mode is CFFI_MODE.ANY
#   Looking for R home with: R RHOME
#   Unable to determine R home: [Errno 2] No such file or directory: 'R'
#   R home found: None
# ...

# %%
from plotnine import *
ggplot(aabbcc, aes('Publication Year', 't1')) + \
                 geom_smooth(se = True, method='lowess') + \
                 labs(x = "Topic proportion", y = "Publication Year" )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotnine/stats/smoothers.py:41, in predictdf(data, xseq, **params)
#      40 try:
# ---> 41     method = methods[method]
#      42 except KeyError:
#
# KeyError: 'gam'
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
# ...

# %%
aabbcc
# Out:
#         Unnamed: 0  author number  funder number  Times Cited, WoS Core  \
# 0                1              2              0                      5
# 1                2              3              0                      8
# 2                3              3              0                      4
# 3                4              3              0                      6
# 4                5              4              0                     20
# ...            ...            ...            ...                    ...
# 122351      122352             12              4                     10
# 122352      122353              2              0                      9
# 122353      122354              6              3                     14
# 122354      122355              8              4                     30
# 122355      122356              4              1                      0
#
#         Publication Year Publication Type  document        t1        t2  \
# ...

# %%
pip install scikit-misc
# Out:
# ...
#      |████████████████████████████████| 13.6 MB 9.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 19.8 MB 10.6 MB/s eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.3 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.3 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
final.columns = ['paper_id', 'Name', 'Country', 'Type'] + label['topic'].tolist()

# %%
final.to_csv('final_data.txt.gz', index = False)

# %%
ff = pd.DataFrame(final[final['Name'] == 'National Science Foundation'].mean())[1:]
ff.columns = ['Proportion']
ff = ff.sort_values('Proportion', ascending = False)
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_32202/4026149094.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#                                Proportion
# Climate Change                   0.038227
# Generic research words           0.032000
# Spatial scale                    0.031114
# Taxonomy                         0.028758
# Species diversity                0.027529
# ...                                   ...
# Marine bird migration            0.002520
# North American wildlife          0.002517
# Plant interaction                0.002435
# UK                               0.002353
# Study impacts and limitations    0.001552
#
# [100 rows x 1 columns]

# %%
# Out:
# Index(['paper_id', 'Times.Cited..All.Databases', 'Publication.Year'], dtype='object')

# %%
topic.columns = label['topic'].tolist() + list(topic.columns[-3:])

# %%
topic.dropna().to_csv('topic.txt.gz', index = False)

# %%
topic[topic['Publication.Year'] >= 1970].dropna().to_csv('topic.txt.gz', index = False)

# %%
list(topic.columns[:100])
# Out:
# ['Wild Mammals',
#  'Protected areas',
#  'Marine mammals',
#  'Primary production',
#  'Antartica aimals',
#  'Deep ocean ',
#  'landscape ecology',
#  'invasive species',
#  'Physiology',
#  'ecosystem services',
#  'genetics',
#  'Site Selection',
#  'Aquatic invertebrates',
#  'movement ecology',
#  'Miscellaneous biotopes',
#  'Plant interaction',
#  'Traditional/indigenous knowledge',
#  'Risk assessment',
#  'North American biogeography',
#  'North American Plains Mammals',
#  'Southern Hemisphere Savannas',
#  'Brazilian biodiversity hotspot',
#  'Taxonomy',
#  'Food webs',
#  'wildfires',
#  'Island',
#  'Climate Change',
#  'Spatial scale',
#  'Animal disease',
#  'Wetlands',
#  'Agriculture',
#  'Urbanization',
#  'Restoration',
#  'Inherited traits',
#  'Amazon',
#  'Marine bird migration',
#  'Estimation (Methods)',
#  'Soil systems',
#  'Seeds',
#  'mark-recapture studies',
#  'Coastal areas',
#  'Forest and Waterfowl Species',
#  'Southern Coast US',
# ...

# %%
final.groupby(['Type', 'Publication.Year']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [152], in <cell line: 1>()
# ----> 1 final.groupby(['Type', 'Publication.Year']).count()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
final
# Out:
#         paper_id                                               Name  \
# 0           1013  Rural Industries Research and Development Corp...
# 1           1056  LOEWE Centre for Translational Biodiversity Ge...
# 2           1056                                Stanford University
# 3           1059                   Environmental Leadership Program
# 4           1064                             The Nature Conservancy
# ...          ...                                                ...
# 148772    122507                                Jefferson Institute
# 148773    122507                   Rensselaer Polytechnic Institute
# 148774    122507                                IBM (United States)
# 148775    122507                        Great Lakes Protection Fund
# 148776    122508  National Council for Scientific and Technologi...
#
#               Country                  Type  North American wildlife  \
# 0           Australia  Nonprofit and Others                 0.000254
# ...

# %%
fn = pd.merge(final, topic[['paper_id', 'Publication.Year']], 'left').drop(['paper_id'], 1)
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_1864/2150968184.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.

# %%
fn
# Out:
#                                                      Name        Country  \
# 0       Rural Industries Research and Development Corp...      Australia
# 1       LOEWE Centre for Translational Biodiversity Ge...        Germany
# 2                                     Stanford University  United States
# 3                        Environmental Leadership Program  United States
# 4                                  The Nature Conservancy  United States
# ...                                                   ...            ...
# 148772                                Jefferson Institute  United States
# 148773                   Rensselaer Polytechnic Institute  United States
# 148774                                IBM (United States)  United States
# 148775                        Great Lakes Protection Fund  United States
# 148776  National Council for Scientific and Technologi...         Brazil
#
#                         Type  North American wildlife  Protected areas  \
# ...

# %%
fnn = fn.groupby(['Type', 'Publication.Year']).mean()

# %%
kk = pd.DataFrame(fnn.index.tolist(), columns = ['type', 'pub'])

# %%
fnn.index = range(len(fnn))
fnn['Type'] = kk['type']
fnn['Publication Year'] = kk['pub']

# %%
fnn.columns = list(topic.columns[:100]) + list(fnn.columns[-2:])

# %%
fnn.to_csv('type.csv', index = False)

# %%
fnn
# Out:
#      Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 0        0.002255         0.029442        0.008336            0.000970
# 1        0.001586         0.026653        0.001299            0.005276
# 2        0.003974         0.014723        0.002645            0.002682
# 3        0.004087         0.009926        0.003689            0.001348
# 4        0.000488         0.025898        0.000750            0.080879
# ..            ...              ...             ...                 ...
# 178      0.004303         0.015771        0.008745            0.009152
# 179      0.003254         0.016412        0.007919            0.008085
# 180      0.003259         0.016361        0.006558            0.007758
# 181      0.004419         0.016513        0.009578            0.008463
# 182      0.001867         0.014195        0.003293            0.007029
#
#      Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
ggplot(fnn[fnn['Publication Year']>=2007], aes('Publication Year', 'Marine mammals', color = 'Type')) + geom_smooth(se = False) + geom_point()
# Out:
# <ggplot: (8761070539367)>

# %%
ggplot(fnn[fnn['Publication Year']>=2007], aes('Publication Year', 'Marine mammals', color = '')) + geom_smooth(se = False) + theme(figure_size=(12, 5)) + geom_point()

# %%
fnn1 = fn.groupby(['Country', 'Publication.Year']).mean()

# %%
kk
# Out:
#                      type     pub
# 0                 Company  1975.0
# 1                 Company  1978.0
# 2                 Company  1980.0
# 3                 Company  1989.0
# 4                 Company  1991.0
# ..                    ...     ...
# 178  Nonprofit and Others  2017.0
# 179  Nonprofit and Others  2018.0
# 180  Nonprofit and Others  2019.0
# 181  Nonprofit and Others  2020.0
# 182  Nonprofit and Others  2021.0
#
# [183 rows x 2 columns]

# %%
kk = pd.DataFrame(fnn1.index.tolist(), columns = ['type', 'pub'])

fnn1.index = range(len(fnn1))
fnn1['Country'] = kk['type']
fnn1['Publication Year'] = kk['pub']

# %%
fnn1.to_csv('country.csv', index = False)

# %%
uu = fn.groupby('Country').count()
iu = fnn1[fnn1['Country'].isin(['United States', 'China'])]

# %%
ggplot(iu, aes('Publication Year', 'Marine mammals', color = 'Country')) + geom_smooth(se = False)
# Out:
# <ggplot: (8761021628986)>

# %%
fnn1
# Out:
#       Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 0         0.000162         0.004368        0.000084            0.000490
# 1         0.000670         0.007739        0.000733            0.000823
# 2         0.002401         0.003588        0.000196            0.002812
# 3         0.000465         0.031648        0.000345            0.000499
# 4         0.000754         0.003612        0.000613            0.000038
# ...            ...              ...             ...                 ...
# 2671      0.000617         0.012621        0.000791            0.000809
# 2672      0.001077         0.044726        0.000897            0.000628
# 2673      0.000795         0.009258        0.002275            0.000425
# 2674      0.000340         0.019178        0.000576            0.000772
# 2675      0.000579         0.016533        0.000670            0.014603
#
#       Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
fn.groupby('Country').count().sort_values('Type', ascending = False).index
# Out:
# Index(['United States', 'China', 'United Kingdom', 'Brazil', 'Canada',
#        'Australia', 'Germany', 'Spain', 'Belgium', 'France',
#        ...
#        'Cayman Islands', 'Lesotho', 'Burkina', 'Congo', 'Cook Islands',
#        'Dominica', 'Eswatini', 'Sao Tome and Principe', 'Guinea', 'Gambia'],
#       dtype='object', name='Country', length=212)

# %%
values = ['<select>',3, 5, 10, 15, 20, 30]
default_ix = values.index(30)

# %%
len(values.index(30)
# Out:
# 6

# %%
fnn1.drop_duplicates('Country')['Country'].tolist()
# Out:
# 'China'

# %%
aa = pd.read_csv('country.csv')

# %%
fnn1
# Out:
#       Wild Mammals  Protected areas  Marine mammals  Primary production  \
# 0         0.000162         0.004368        0.000084            0.000490
# 1         0.000670         0.007739        0.000733            0.000823
# 2         0.002401         0.003588        0.000196            0.002812
# 3         0.000465         0.031648        0.000345            0.000499
# 4         0.000754         0.003612        0.000613            0.000038
# ...            ...              ...             ...                 ...
# 2671      0.000617         0.012621        0.000791            0.000809
# 2672      0.001077         0.044726        0.000897            0.000628
# 2673      0.000795         0.009258        0.002275            0.000425
# 2674      0.000340         0.019178        0.000576            0.000772
# 2675      0.000579         0.016533        0.000670            0.014603
#
#       Antartica aimals  Deep ocean   landscape ecology  invasive species  \
# ...

# %%
bb = aa[aa['Publication Year']>=2007][aa['Publication Year']!=2021][aa['Country'].isin(['United States', 'China'])]
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_1864/1433833618.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
ggplot(bb, aes('Publication Year', 'Wild Mammals', color = 'Country')) + geom_smooth(se = False) + geom_point()
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotnine/mapping/evaluation.py:219, in evaluate(aesthetics, data, env)
#     218 try:
# --> 219     new_val = env.eval(col, inner_namespace=data)
#     220 except Exception as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:164, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     156 """Evaluate some Python code in the encapsulated environment.
#     157
#     158 :arg expr: A string containing a Python expression.
#    (...)
#     162 :returns: The value of `expr`.
#     163 """
# --> 164 code = compile(expr, source_name, "eval", self.flags, False)
#     165 return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                     + self._namespaces))
#
# ...

# %%
fnn1.columns = list(topic.columns[:100]) + ['Country', 'Publication Year']

# %%
default_ix = values.index(30)

# %%
fnn1[fnn1['Publication Year']>=2007][fnn1['Publication Year']!=2021][fnn1['Country'].isin(['United States', 'China'])]
# Out:
# /var/folders/zs/ndm5fy256gqc0v1z9h24c8l00000gq/T/ipykernel_1864/3058988181.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       North American wildlife  Protected areas  Marine mammals  \
# 452                  0.001543         0.012613        0.001049
# 453                  0.001650         0.013057        0.002274
# 454                  0.004707         0.012712        0.002286
# 455                  0.002998         0.010137        0.001216
# 456                  0.002830         0.013293        0.001896
# 457                  0.005144         0.013988        0.003603
# 458                  0.003170         0.016560        0.003219
# 459                  0.001602         0.013331        0.003206
# 460                  0.002134         0.014576        0.003877
# 461                  0.000975         0.012439        0.001326
# 462                  0.001574         0.014117        0.001789
# ...
